# %%
#importing neccesary libraries
import numpy as np,pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
#checking the statisicall parameters
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
#getting to know the data and there format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
# checking the missing values
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %% [markdown]
# ### univariant analysis

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
#dropping the unique identifer column
print(df.shape)
df.drop('name',axis=1,inplace=True)
print(df.shape)
# Out:
# (4340, 8)
# (4340, 7)

# %%
df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
# checking for unique classes
df['fuel'].value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
#visualizing the column
sns.countplot(df['fuel'])
plt.title('fuel')
plt.show()

# %%
#checking counts of classes in percentage
df['fuel'].value_counts()/len(df)*100
# Out:
# Diesel      49.608295
# Petrol      48.917051
# CNG          0.921659
# LPG          0.529954
# Electric     0.023041
# Name: fuel, dtype: float64

# %% [markdown]
# ### because the last three classes have very less values. we will drop them

# %%
#creating dataframe with the fuel column containing petrol and diesel
data = df[(df['fuel'] == 'Petrol') | (df['fuel'] == 'Diesel')]
data['fuel'].value_counts()
# Out:
# Diesel    2153
# Petrol    2123
# Name: fuel, dtype: int64

# %%
#label encoding the classes
data['fuel'] = data['fuel'].map({'Diesel':1,'Petrol':2})
data
# Out:
#       year  selling_price  km_driven  fuel seller_type transmission  \
# 0     2007          60000      70000     2  Individual       Manual
# 1     2007         135000      50000     2  Individual       Manual
# 2     2012         600000     100000     1  Individual       Manual
# 3     2017         250000      46000     2  Individual       Manual
# 4     2014         450000     141000     1  Individual       Manual
# ...    ...            ...        ...   ...         ...          ...
# 4335  2014         409999      80000     1  Individual       Manual
# 4336  2014         409999      80000     1  Individual       Manual
# 4337  2009         110000      83000     2  Individual       Manual
# 4338  2016         865000      90000     1  Individual       Manual
# 4339  2016         225000      40000     2  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...            ...
# 4335  Second Owner
# 4336  Second Owner
# 4337  Second Owner
# 4338   First Owner
# 4339   First Owner
#
# [4276 rows x 7 columns]

# %%
# checking values counts in percentage
df.seller_type.value_counts()/len(df)*100
# Out:
# Individual          74.746544
# Dealer              22.903226
# Trustmark Dealer     2.350230
# Name: seller_type, dtype: float64

# %%
#we will perform one_hot_encoding
dummy = pd.get_dummies(df.seller_type,prefix='seller_type')
print(df.shape)
df.drop('seller_type',inplace=True,axis=1)
print(df.shape)
df = pd.concat([dummy,df],axis=1)
df
# Out:
# (4340, 7)
# (4340, 6)
#       seller_type_Dealer  seller_type_Individual  \
# 0                      0                       1
# 1                      0                       1
# 2                      0                       1
# 3                      0                       1
# 4                      0                       1
# ...                  ...                     ...
# 4335                   0                       1
# 4336                   0                       1
# 4337                   0                       1
# 4338                   0                       1
# 4339                   0                       1
#
#       seller_type_Trustmark Dealer  year  selling_price  km_driven    fuel  \
# 0                                0  2007          60000      70000  Petrol
# 1                                0  2007         135000      50000  Petrol
# 2                                0  2012         600000     100000  Diesel
# 3                                0  2017         250000      46000  Petrol
# 4                                0  2014         450000     141000  Diesel
# ...                            ...   ...            ...        ...     ...
# 4335                             0  2014         409999      80000  Diesel
# 4336                             0  2014         409999      80000  Diesel
# 4337                             0  2009         110000      83000  Petrol
# 4338                             0  2016         865000      90000  Diesel
# 4339                             0  2016         225000      40000  Petrol
#
#      transmission         owner
# 0          Manual   First Owner
# 1          Manual   First Owner
# 2          Manual   First Owner
# 3          Manual   First Owner
# 4          Manual  Second Owner
# ...           ...           ...
# 4335       Manual  Second Owner
# 4336       Manual  Second Owner
# 4337       Manual  Second Owner
# 4338       Manual   First Owner
# 4339       Manual   First Owner
#
# [4340 rows x 9 columns]

# %%
#checking the value counts of the column
df['transmission'].value_counts()
# Out:
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64

# %%
#we will perform label encoding
df.transmission = df.transmission.map({'Manual':1,'Automatic':2})
df
# Out:
#       seller_type_Dealer  seller_type_Individual  \
# 0                      0                       1
# 1                      0                       1
# 2                      0                       1
# 3                      0                       1
# 4                      0                       1
# ...                  ...                     ...
# 4335                   0                       1
# 4336                   0                       1
# 4337                   0                       1
# 4338                   0                       1
# 4339                   0                       1
#
#       seller_type_Trustmark Dealer  year  selling_price  km_driven    fuel  \
# 0                                0  2007          60000      70000  Petrol
# 1                                0  2007         135000      50000  Petrol
# 2                                0  2012         600000     100000  Diesel
# 3                                0  2017         250000      46000  Petrol
# 4                                0  2014         450000     141000  Diesel
# ...                            ...   ...            ...        ...     ...
# 4335                             0  2014         409999      80000  Diesel
# 4336                             0  2014         409999      80000  Diesel
# 4337                             0  2009         110000      83000  Petrol
# 4338                             0  2016         865000      90000  Diesel
# 4339                             0  2016         225000      40000  Petrol
#
#       transmission         owner
# 0                1   First Owner
# 1                1   First Owner
# 2                1   First Owner
# 3                1   First Owner
# 4                1  Second Owner
# ...            ...           ...
# 4335             1  Second Owner
# 4336             1  Second Owner
# 4337             1  Second Owner
# 4338             1   First Owner
# 4339             1   First Owner
#
# [4340 rows x 9 columns]

# %%
df.owner.value_counts()/len(df)*100
# Out:
# First Owner             65.253456
# Second Owner            25.483871
# Third Owner              7.004608
# Fourth & Above Owner     1.866359
# Test Drive Car           0.391705
# Name: owner, dtype: float64

# %%
df.owner = df.owner.map({'Third Owner':'Others','Fourth & Above Owner':'Others','Test Drive Car':'Others'})
df
# Out:
#       seller_type_Dealer  seller_type_Individual  \
# 0                      0                       1
# 1                      0                       1
# 2                      0                       1
# 3                      0                       1
# 4                      0                       1
# ...                  ...                     ...
# 4335                   0                       1
# 4336                   0                       1
# 4337                   0                       1
# 4338                   0                       1
# 4339                   0                       1
#
#       seller_type_Trustmark Dealer  year  selling_price  km_driven    fuel  \
# 0                                0  2007          60000      70000  Petrol
# 1                                0  2007         135000      50000  Petrol
# 2                                0  2012         600000     100000  Diesel
# 3                                0  2017         250000      46000  Petrol
# 4                                0  2014         450000     141000  Diesel
# ...                            ...   ...            ...        ...     ...
# 4335                             0  2014         409999      80000  Diesel
# 4336                             0  2014         409999      80000  Diesel
# 4337                             0  2009         110000      83000  Petrol
# 4338                             0  2016         865000      90000  Diesel
# 4339                             0  2016         225000      40000  Petrol
#
#       transmission owner
# 0                1   NaN
# 1                1   NaN
# 2                1   NaN
# 3                1   NaN
# 4                1   NaN
# ...            ...   ...
# 4335             1   NaN
# 4336             1   NaN
# 4337             1   NaN
# 4338             1   NaN
# 4339             1   NaN
#
# [4340 rows x 9 columns]
